# %% [markdown]
#  Q1: What is TensorFlow 2.0, and how is it different from TensorFlow 1.x?
#
# **Answer:**
# TensorFlow 2.0 is a deep learning library by Google. It’s more **Python-friendly**, supports **eager execution** by default, and makes building models easier using **Keras**.
#
# **Differences from 1.x:**
# - TF 1.x: Uses sessions and placeholders, harder to debug
# - TF 2.x: Eager execution, simpler API, no need for sessions
# - TF 2.x encourages a more intuitive, Keras-based workflow

# %% [markdown]
#  Q2: How do you install TensorFlow 2.0?
#
# **Answer:**
# You can install TensorFlow 2.0 using pip:
#
# pip install tensorflow==2.0.0

# %% [markdown]
# Q3: What is the primary function of tf.function in TensorFlow 2.0?
#
# **Answer:**
# tf.function converts a Python function into a TensorFlow graph , which makes it run faster.

# %% [markdown]
#  Q4: What is the purpose of the Model class in TensorFlow 2.0?
#
# **Answer:**
# tf.keras.Model is like the blueprint for your neural network. It stores layers, loss functions, metrics, and can be trained using .fit()
#
# You can also create custom models by inheriting from it.

# %% [markdown]
# Q5: How do you create a neural network using TensorFlow 2.0?
#
# **Answer:**
#
# import tensorflow as tf
# from tensorflow.keras import layers, models
#
# model = models.Sequential([
#     layers.Dense(64, activation='relu', input_shape=(input_dim,)),
#     layers.Dense(10, activation='softmax')
# ])
#
# model.compile(optimizer='adam',
#               loss='sparse_categorical_crossentropy',
#               metrics=['accuracy'])
#
# model.fit(X_train, y_train, epochs=10)

# %% [markdown]
#  Q6: What is the importance of tensor Space in TensorFlow 2.0?
#
# **Answer:**
# Tensors are like multidimensional arrays.
# - They store input data, outputs, and weights.
# - They are the core data structure for all TensorFlow computations.

# %% [markdown]
# Q7: How can TensorBoard be integrated with TensorFlow 2.0?
#
# **Answer:**
# TensorBoard is used for visualizing training metrics.

# %% [markdown]
# Q8: What is the purpose of TensorFlow Playground?
#
# **Answer:**
# It’s an interactive web app to play with simple neural networks visually.
# You can change layers, neurons, activation functions, and see how the network learns in real-time. Great for beginners.

# %% [markdown]
# Q9: What is Netron, and how is it useful for deep learning models?
#
# **Answer:**
# Netron is a model visualizer. It can open TensorFlow, PyTorch, ONNX, and other models.
#
# It’s useful to:
# - Check architecture
# - Inspect layer shapes
# - Verify weights and parameters

# %% [markdown]
# Q10: What is the difference between TensorFlow and PyTorch?
#
# **Answer:**
#
# | Feature | TensorFlow | PyTorch |
# |---------|-----------|---------|
# | Execution | Graph + Eager | Eager by default |
# | API | Keras high-level API | Pythonic and imperative |
# | Deployment | TensorFlow Serving, TFLite | TorchServe, ONNX |
# | Use Case | Production-ready | Research-friendly |
#
# Basically, TensorFlow is more production-oriented, PyTorch is more flexible and beginner-friendly.

# %% [markdown]
# Q11: How do you install PyTorch?
#
# **Answer:**
# Use pip:
#
# ```bash
# pip install torch torchvision torchaudio

# %% [markdown]
# Q12: What is the basic structure of a PyTorch neural network?
#
# **Answer:**
#
# ```python
# import torch
# import torch.nn as nn
#
# class SimpleNN(nn.Module):
#     def __init__(self):
#         super(SimpleNN, self).__init__()
#         self.fc1 = nn.Linear(784, 128)
#         self.relu = nn.ReLU()
#         self.fc2 = nn.Linear(128, 10)
#
#     def forward(self, x):
#         x = self.relu(self.fc1(x))
#         x = self.fc2(x)
#         return x

# %% [markdown]
# Q13: What is the significance of tensors in PyTorch?
#
# **Answer:**
# Tensors are multi-dimensional arrays, just like in TensorFlow.
# - They are used for all computations.
# - Enable autograd, i.e., automatic differentiation for training.

# %% [markdown]
# Q14: What is the difference between `torch.Tensor` and `torch.cuda.Tensor`?
#
# **Answer:**
# - torch.Tensor → Stored on CPU
# - torch.cuda.Tensor → Stored on GPU for faster computation

# %% [markdown]
# Q15: What is the purpose of the torch.optim module?
#
# **Answer:**
# It contains optimizers like SGD, Adam, RMSProp that update model weights during training.

# %% [markdown]
# Q16: What are some common activation functions used in neural networks?
#
# **Answer:**
# - ReLU → Rectified Linear Unit
# - Sigmoid → 0 to 1 output
# - Tanh → -1 to 1 output
# - Leaky ReLU → Avoids dying neurons
# - Softmax → Converts logits to probabilities

# %% [markdown]
#  Q17: What is the difference between torch.nn.Module and torch.nn.Sequential?
#
# **Answer:**
# - Module → Base class, allows custom forward pass
# - Sequential → Stack layers in order, simple models only

# %% [markdown]
# Q18: How can you monitor training progress in TensorFlow 2.0?
#
# **Answer:**
# - Use TensorBoard
# - Use model.evaluate() on validation set
# - Use callbacks like tf.keras.callbacks.EarlyStopping to track metrics

# %% [markdown]
# Q19: How does the Keras API fit into TensorFlow 2.0?
#
# **Answer:**
# Keras is the default high-level API for building and training models.
# - Makes TensorFlow easy to use
# - You can write fewer lines of code for complex models.

# %%
# Q20: Give an example of a deep learning project in TensorFlow 2.0.

# **Answer:**  
# **Image classification using CNN on MNIST dataset:**

# ```python
import tensorflow as tf
from tensorflow.keras.datasets import mnist
from tensorflow.keras import models, layers
from sklearn.model_selection import train_test_split

(X_train, y_train), (X_test, y_test) = mnist.load_data()
X_train = X_train.reshape(-1,28,28,1)/255.0
X_test = X_test.reshape(-1,28,28,1)/255.0

model = models.Sequential([
    layers.Conv2D(32, (3,3), activation='relu', input_shape=(28,28,1)),
    layers.MaxPooling2D((2,2)),
    layers.Flatten(),
    layers.Dense(10, activation='softmax')
])

model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model.fit(X_train, y_train, epochs=5, validation_data=(X_test, y_test))
# Out:
# c:\Users\krish\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 19s 9ms/step - accuracy: 0.9392 - loss: 0.2124 - val_accuracy: 0.9738 - val_loss: 0.0845
# Epoch 2/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - accuracy: 0.9781 - loss: 0.0765 - val_accuracy: 0.9767 - val_loss: 0.0724
# Epoch 3/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.9823 - loss: 0.0597 - val_accuracy: 0.9808 - val_loss: 0.0586
# Epoch 4/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9850 - loss: 0.0499 - val_accuracy: 0.9821 - val_loss: 0.0542
# Epoch 5/5
# ...

# %% [markdown]
# Q21: What is the main advantage of using pre-trained models in TensorFlow and PyTorch?
#
# **Answer:**
# - Saves time and computation
# - Useful for transfer learning
# - Leverages knowledge from large datasets
# - Can fine-tune for your specific task

# %%
# Q1: How do you install and verify that TensorFlow 2.0 was installed successfully
# pip install tensorflow==2.0.0
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.20.0

# %%
# Q2: How can you define a simple function in TensorFlow 2.0 to perform addition
import tensorflow as tf

@tf.function
def add(a, b):
    return a + b

print(add(5, 7))
# Out:
# tf.Tensor(12, shape=(), dtype=int32)

# %%
# Q3: How can you create a simple neural network in TensorFlow 2.0 with one hidden layer
from tensorflow import keras
from tensorflow.keras import models, layers

model = models.Sequential([
    layers.Dense(32, activation='relu', input_shape=(10,)),
    layers.Dense(1, activation='linear')
])

model.compile(optimizer='adam', loss='mse', metrics=['mae'])
# Out:
# c:\Users\krish\Lib\site-packages\keras\src\layers\core\dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# Q4: How can you visualize the training progress using TensorFlow and Matplotlib
import matplotlib.pyplot as plt
history = {'loss':[0.9,0.7,0.5,0.3], 'val_loss':[1.0,0.8,0.6,0.4]}  # example data

plt.plot(history['loss'], label='Training Loss')
plt.plot(history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# !pip install torch torchvision torchaudio

# %%
# Q5: How do you install PyTorch and verify the PyTorch installation

import torch
print(torch.__version__)
print(torch.cuda.is_available())

# %%
# Q6: How do you create a simple neural network in PyTorch
import torch
import torch.nn as nn

class SimpleNN(nn.Module):
    def __init__(self):
        super(SimpleNN, self).__init__()
        self.fc1 = nn.Linear(10, 32)
        self.relu = nn.ReLU()
        self.fc2 = nn.Linear(32, 1)
    
    def forward(self, x):
        x = self.relu(self.fc1(x))
        x = self.fc2(x)
        return x

model = SimpleNN()
print(model)

# %%
# Q7: How do you define a loss function and optimizer in PyTorch
import torch.optim as optim
criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

# %%
# Q8: How do you implement a custom loss function in PyTorch
import torch

class CustomLoss(nn.Module):
    def __init__(self):
        super(CustomLoss, self).__init__()
    
    def forward(self, y_pred, y_true):
        return torch.mean((y_pred - y_true)**2 + 0.1*torch.abs(y_pred - y_true))

criterion = CustomLoss()

# %%
# Q9: How do you save and load a TensorFlow model?
from tensorflow.keras import models

# Save model
# model.save('my_model.h5')

# Load model
# loaded_model = models.load_model('my_model.h5')
